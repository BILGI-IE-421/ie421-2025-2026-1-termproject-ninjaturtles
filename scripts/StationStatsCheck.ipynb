# %%
import pandas as pd

# 1. Dosyayı Oku
df = pd.read_csv("station_stats.csv")

print(f"Silinmeden Önceki Satır Sayısı: {len(df)}")

# 2. İsmi veya ID'si olmayan satırları sil (Drop NaNs)
df_clean = df.dropna(subset=['start_station_id'])

print(f" Silinmeden Sonraki Satır Sayısı: {len(df_clean)}")
print(f" Silinen 'Kimliksiz' Satır Sayısı: {len(df) - len(df_clean)}")

# 3. Temiz halini üzerine kaydet
df_clean.to_csv("station_stats.csv", index=False)
print(" Dosya güncellendi")
# Out:
# 🧹 Temizlik Öncesi Satır Sayısı: 2416
# ✨ Temizlik Sonrası Satır Sayısı: 2331
# 🗑️ Silinen 'Kimliksiz' Satır Sayısı: 85
# ✅ Dosya güncellendi ve temizlendi.
